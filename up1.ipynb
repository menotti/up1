# %% [markdown]
# <a href="https://colab.research.google.com/github/menotti/up1/blob/master/up1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install iverilog
# !git clone https://github.com/menotti/up1
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# iverilog is already the newest version (11.0-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# fatal: destination path 'up1' already exists and is not an empty directory.

# %%
# !cd up1/assembler/ && python assembler.py fibo.asm && cp fibo.bin ../processor
# Out:
# Label: loop address 0
# Data declaration a
# Data declaration b
# Data declaration c
# Data: 3 / 16
# Video: 0 / 80
# Unused: 32
# Code: 8 / 128
# Time:  0.0005719661712646484 s

# %%
# !cd up1/processor/ && iverilog *.v && ./a.out
# Out:
# time acc  pc  ir mar mbr we
# VCD info: dumpfile dump.vcd opened for output.
#    0   x   0   x   x   x x
#   30   x   1   x   0  64 0
#   40   x   1  64 240   0 0
#   50   0   1  64 240   0 0
#   60   0   2  64   1  81 0
#   70   0   2  81 241   1 0
#   80   1   2  81 241   1 0
#   90   1   3  81   2  50 0
#  100   1   3  50 242   0 0
#  110   1   3  50 242   1 1
#  120   1   4  50   3  65 0
#  130   1   4  65 241   1 0
#  150   1   5  65   4  48 0
#  160   1   5  48 240   0 0
#  170   1   5  48 240   1 1
#  180   1   6  48   5  66 0
#  190   1   6  66 242   1 0
#  210   1   7  66   6  49 0
#  220   1   7  49 241   1 0
#  230   1   7  49 241   1 1
#  240   1   8  49   7 128 0
#  250   1   8 128 240   1 0
#  260   1   0 128 240   1 0
#  270   1   1 128   0  64 0
#  280   1   1  64 240   1 0
#  300   1   2  64   1  81 0
#  310   1   2  81 241   1 0
#  320   2   2  81 241   1 0
#  330   2   3  81   2  50 0
#  340   2   3  50 242   1 0
#  350   2   3  50 242   2 1
# ...
